# %%
import pandas as pd
import numpy as np


file_partite = 'data_totale_SLAMS_games.xlsx'
file_partite_read = pd.read_excel( file_partite )
file_partite_data = pd.DataFrame( file_partite_read )
file_partite_data


file_date_tornei = 'dataframe_interesse_SLAMS.xlsx'
file_date_tornei_read = pd.read_excel( file_date_tornei )
file_date_tornei_data = pd.DataFrame( file_date_tornei_read )

# %%
file_partite_data.drop( columns=['unicode'], inplace=True )

# %%
file_date_tornei_data
# Out:
#     Unnamed: 0           tornei        data data_parsed UNICODE_LOCATIONS
# 0          186  Australian Open  14.01.2002  2002-01-14    AustralianOPEN
# 1          117      French Open  27.05.2002  2002-05-27      RolandGARROS
# 2          102        Wimbledon  24.06.2002  2002-06-24         WIMBLEDON
# 3           55          US Open  26.08.2002  2002-08-26            UsOPEN
# 4          397  Australian Open  12.01.2003  2003-01-12    AustralianOPEN
# ..         ...              ...         ...         ...               ...
# 74        4379          US Open  31.08.2020  2020-08-31            UsOPEN
# 75        4368      French Open  27.09.2020  2020-09-27      RolandGARROS
# 76        4694  Australian Open  08.02.2021  2021-02-08    AustralianOPEN
# 77        4629      French Open  30.05.2021  2021-05-30      RolandGARROS
# 78        4607        Wimbledon  28.06.2021  2021-06-28         WIMBLEDON
#
# [79 rows x 5 columns]

# %%
data_parsed_partite = []
conto = 0

for idx, v in enumerate ( file_partite_data.PARTITE ):
    for ind, val in enumerate ( file_date_tornei_data.UNICODE_LOCATIONS ):
            locat = v.split("_")[4]
            date_partita = v.split("_")[5]
            if locat==val :
                if date_partita in file_date_tornei_data.data[ind]:
                    data_parsed_partite.append( file_date_tornei_data.data_parsed[ind] )
            

                    
print( len( data_parsed_partite ))            
print( data_parsed_partite )
# Out:
# 2340
# [Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2002-01-14 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2003-01-12 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2004-01-18 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2005-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2006-01-16 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2007-01-15 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2008-01-14 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 00:00:00'), Timestamp('2009-01-19 ...

# %%
data_parsed_partite = pd.Series( data_parsed_partite )
conti = data_parsed_partite.value_counts()

for v in conti :
    print( v )
# Out:
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30

# %%
file_partite_data['data_parsed'] = data_parsed_partite
file_partite_data = file_partite_data.sort_values( by='data_parsed')
unicode = []
conteggio = 0
for v in file_partite_data.PARTITE:
    conteggio = conteggio+1
    unicode.append( conteggio )
    

file_partite_data['unicode'] = unicode

file_partite_data
# Out:
#                                               PARTITE  set_p1  set_p2  \
# 0        F_JOHANSSON_SAFIN_3_AustralianOPEN_2002_SLAM       3       1
# 302    SF_NOVAK_JOHANSSON_3_AustralianOPEN_2002_SLAM_       2       3
# 303         QRT_RIOS_HAAS_3_AustralianOPEN_2002_SLAM_       1       3
# 304    QRT_FERREIRA_SAFIN_3_AustralianOPEN_2002_SLAM_       0       1
# 305      QRT_KOUBEK_NOVAK_3_AustralianOPEN_2002_SLAM_       0       3
# ...                                               ...     ...     ...
# 1759       QRT_FEDERER_HURKACZ_3_WIMBLEDON_2021_SLAM_       0       3
# 1760    QRT_FUCSOVICS_DJOKOVIC_3_WIMBLEDON_2021_SLAM_       0       3
# 1761  QRT_KHACHANOV_SHAPOVALOV_3_WIMBLEDON_2021_SLAM_       2       3
# 1483        OTT_KHACHANOV_KORDA_3_WIMBLEDON_2021_SLAM       3       2
# 1755     F_BERRETTINI_DJOKOVIC_3_WIMBLEDON_2021_SLAM_       1       3
#
#      games_1_set1 games_1_set2 games_1_set3 games_1_set4 games_1_set5  \
# 0               3            6            6            7
# 302             6            6            6            3            4
# 303             6            4            7            6
# 304             2
# 305             2            3            2
# ...           ...          ...          ...          ...          ...
# 1759            3           64            0
# 1760            3            4            4
# 1761            4            6            7            1            4
# 1483            3            6            6            5           10
# 1755            7            4            4            3
#
#      games_2_set1 games_2_set2 games_2_set3 games_2_set4 games_2_set5  segno  \
# 0               6            4            4            6                   1
# 302             7            0            4            6            6      2
# 303             7            6            6            7                   2
# 304             5                                                          2
# 305             6            6            6                                2
# ...           ...          ...          ...          ...          ...    ...
# 1759            6            7            6                                2
# 1760            6            6            6                                2
# 1761            6            3            5            6            6      2
# 1483            6            4            3            7            8      1
# 1755           64            6            6            6                   2
#
#      data_parsed  unicode
# 0     2002-01-14        1
# 302   2002-01-14        2
# 303   2002-01-14        3
# 304   2002-01-14        4
# 305   2002-01-14        5
# ...          ...      ...
# 1759  2021-06-28     2336
# 1760  2021-06-28     2337
# 1761  2021-06-28     2338
# 1483  2021-06-28     2339
# 1755  2021-06-28     2340
#
# [2340 rows x 16 columns]

# %%
print( len( file_partite_data.PARTITE ) )
# Out:
# 2340

# %%
file_partite_data
# Out:
#                                               PARTITE  set_p1  set_p2  \
# 0        F_JOHANSSON_SAFIN_3_AustralianOPEN_2002_SLAM       3       1
# 302    SF_NOVAK_JOHANSSON_3_AustralianOPEN_2002_SLAM_       2       3
# 303         QRT_RIOS_HAAS_3_AustralianOPEN_2002_SLAM_       1       3
# 304    QRT_FERREIRA_SAFIN_3_AustralianOPEN_2002_SLAM_       0       1
# 305      QRT_KOUBEK_NOVAK_3_AustralianOPEN_2002_SLAM_       0       3
# ...                                               ...     ...     ...
# 1759       QRT_FEDERER_HURKACZ_3_WIMBLEDON_2021_SLAM_       0       3
# 1760    QRT_FUCSOVICS_DJOKOVIC_3_WIMBLEDON_2021_SLAM_       0       3
# 1761  QRT_KHACHANOV_SHAPOVALOV_3_WIMBLEDON_2021_SLAM_       2       3
# 1483        OTT_KHACHANOV_KORDA_3_WIMBLEDON_2021_SLAM       3       2
# 1755     F_BERRETTINI_DJOKOVIC_3_WIMBLEDON_2021_SLAM_       1       3
#
#      games_1_set1 games_1_set2 games_1_set3 games_1_set4 games_1_set5  \
# 0               3            6            6            7
# 302             6            6            6            3            4
# 303             6            4            7            6
# 304             2
# 305             2            3            2
# ...           ...          ...          ...          ...          ...
# 1759            3           64            0
# 1760            3            4            4
# 1761            4            6            7            1            4
# 1483            3            6            6            5           10
# 1755            7            4            4            3
#
#      games_2_set1 games_2_set2 games_2_set3 games_2_set4 games_2_set5  segno  \
# 0               6            4            4            6                   1
# 302             7            0            4            6            6      2
# 303             7            6            6            7                   2
# 304             5                                                          2
# 305             6            6            6                                2
# ...           ...          ...          ...          ...          ...    ...
# 1759            6            7            6                                2
# 1760            6            6            6                                2
# 1761            6            3            5            6            6      2
# 1483            6            4            3            7            8      1
# 1755           64            6            6            6                   2
#
#      data_parsed  unicode
# 0     2002-01-14        1
# 302   2002-01-14        2
# 303   2002-01-14        3
# 304   2002-01-14        4
# 305   2002-01-14        5
# ...          ...      ...
# 1759  2021-06-28     2336
# 1760  2021-06-28     2337
# 1761  2021-06-28     2338
# 1483  2021-06-28     2339
# 1755  2021-06-28     2340
#
# [2340 rows x 16 columns]

# %%
file_partite_data.to_excel("file_partite_data_parsed_SLAMS_games.xlsx")
